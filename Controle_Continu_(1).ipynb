# %% [markdown]
# <a href="https://colab.research.google.com/github/essanfelix/7688581-Expert-Git-GitHub/blob/main/Controle_Continu_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Iris DataSet  Visulaizations using seaborn

# %% [markdown]
# ## Exercice 1
#
# On considère pour cet exercice, le dataset Iris  qui représente un ensemble de données qui comprend 50 échantillons de chacune des trois espèces d’Iris (Iris setosa, Iris virginica et Iris versicolor).
#
# Quatre caractéristiques sont mesurées à partir de chaque échantillon: la longueur et la largeur des sépales et des pétales, en centimètres.
#
#
# 1- reconstruire les visualisations ci-dessous en utilisant le dataset Iris. n'oubliez pas de préciser les lables des axes x et y et de donner un titre à chaque graphe.
#
# 2- proposer une autre visualisation différente, plus optimale que celle proposée (type, couleurs..), justifier votre choix
#
# 3- interpréter chaque visualisation

# %%
# Import libraries

import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data_file = pd.read_csv('iris.csv' , index_col = 'idx')

# %%
data_file.head()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width variety
# idx
# 1             5.1          3.5           1.4          0.2  Setosa
# 2             4.9          3.0           1.4          0.2  Setosa
# 3             4.7          3.2           1.3          0.2  Setosa
# 4             4.6          3.1           1.5          0.2  Setosa
# 5             5.0          3.6           1.4          0.2  Setosa

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
# Out:
# Text(0, 0.5, 'Value')

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
##
# Out:
# Text(0, 0.5, 'Value')

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
##
# Out:
# <AxesSubplot:title={'center':'Plotting values of determined one Feature '}, xlabel='idx', ylabel='petal.length'>

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
##
# Out:
# <AxesSubplot:title={'center':'Heat Map of Features'}, ylabel='idx'>

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
##
# Out:
# <AxesSubplot:title={'center':'Scatter Plot of two Features colored by other feature (categorical)'}, xlabel='sepal.length', ylabel='sepal.width'>

# %%
##

# %%
##
# Out:
# <AxesSubplot:title={'center':'Scatter Plot of two Features with one regression line'}, xlabel='sepal.length', ylabel='sepal.width'>

# %%
##

# %%
##

# %%
##

# %%
##

# %% [markdown]
# ## Exercice 2
#
# On considère pour cet exercice, le dataset video_games_sales représenté sur [kaggle](https://www.kaggle.com/datasets/rush4ratio/video-game-sales-with-ratings)
#
# 1- reconstruire les visualisations ci-dessous en utilisant le dataset video_games_sales. n'oubliez pas de préciser les lables des axes x et y et rajouter un titre à chaque graphe.
#
# 2- interpréter chaque visualisation

# %%
df = pd.read_csv('/content/Video_Games_Sales_as_at_22_Dec_2016.csv').dropna()
print(df.shape)
# Out:
# (6825, 16)

# %%
useful_cols = ['Name', 'Platform', 'Year_of_Release', 'Genre',
               'Global_Sales', 'Critic_Score', 'Critic_Count',
               'User_Score', 'User_Count', 'Rating'
              ]
df[useful_cols].head()
# Out:
#                     Name Platform  Year_of_Release     Genre  Global_Sales  \
# 0             Wii Sports      Wii           2006.0    Sports         82.53
# 2         Mario Kart Wii      Wii           2008.0    Racing         35.52
# 3      Wii Sports Resort      Wii           2009.0    Sports         32.77
# 6  New Super Mario Bros.       DS           2006.0  Platform         29.80
# 7               Wii Play      Wii           2006.0      Misc         28.92
#
#    Critic_Score  Critic_Count User_Score  User_Count Rating
# 0          76.0          51.0          8       322.0      E
# 2          82.0          73.0        8.3       709.0      E
# 3          80.0          73.0          8       192.0      E
# 6          89.0          65.0        8.5       431.0      E
# 7          58.0          41.0        6.6       129.0      E

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
##

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-ea997e4b3ee2> in <cell line: 0>()
#       3
#       4 # Calculer les corrélations
# ----> 5 correlation_matrix = df_selected.corr()
#       6
#       7 # Heatmap des corrélations
#
# NameError: name 'df_selected' is not defined

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
##
# Out:
# C:\Users\manel\miniconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
##

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
##
